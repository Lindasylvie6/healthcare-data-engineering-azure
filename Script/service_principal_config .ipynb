# %%
# Configuration (Service Principal + ADLS Gen2)
storage_account_name = "adlshospitaldwh"
container_landing = "landing"
container_bronze = "bronze"
container_silver = "silver"
container_gold = "gold"

# Service Principal credentials
application_id = "ad3497a3-a8be-4251-8e01-4b7bc1c781b4"
tenant_id = "2be11f7b-4e63-4e64-b8a4-992816fe3359"
client_secret = "********"

# Configure Service Principal authentication
spark.conf.set(f"fs.azure.account.auth.type.{storage_account_name}.dfs.core.windows.net", "OAuth")
spark.conf.set(f"fs.azure.account.oauth.provider.type.{storage_account_name}.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set(f"fs.azure.account.oauth2.client.id.{storage_account_name}.dfs.core.windows.net", application_id)
spark.conf.set(f"fs.azure.account.oauth2.client.secret.{storage_account_name}.dfs.core.windows.net", client_secret)
spark.conf.set(f"fs.azure.account.oauth2.client.endpoint.{storage_account_name}.dfs.core.windows.net", f"https://login.microsoftonline.com/{tenant_id}/oauth2/token")

# Paths using abfss://
LANDING_PATH = f"abfss://{container_landing}@{storage_account_name}.dfs.core.windows.net/"
BRONZE_PATH = f"abfss://{container_bronze}@{storage_account_name}.dfs.core.windows.net/"
SILVER_PATH = f"abfss://{container_silver}@{storage_account_name}.dfs.core.windows.net/"
GOLD_PATH = f"abfss://{container_gold}@{storage_account_name}.dfs.core.windows.net/"

print("Configuration complete")
print(f"Landing path: {LANDING_PATH}")
print(f"Bronze path: {BRONZE_PATH}")
print(f"Silver path: {SILVER_PATH}")
print(f"Gold path: {GOLD_PATH}")
# Out:
# Configuration complete
# Landing path: abfss://landing@adlshospitaldwh.dfs.core.windows.net/
# Bronze path: abfss://bronze@adlshospitaldwh.dfs.core.windows.net/
# Silver path: abfss://silver@adlshospitaldwh.dfs.core.windows.net/
# Gold path: abfss://gold@adlshospitaldwh.dfs.core.windows.net/

# %%
# Check landing container
display(dbutils.fs.ls(LANDING_PATH))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>abfss://landing@adlshospitaldwh.dfs.core.windows.net/claims_and_billing.csv</td><td>claims_and_billing.csv</td><td>6605002</td><td>1779297413000</td></tr><tr><td>abfss://landing@adlshospitaldwh.dfs.core.windows.net/denials.csv</td><td>denials.csv</td><td>737764</td><td>1779297409000</td></tr><tr><td>abfss://landing@adlshospitaldwh.dfs.core.windows.net/diagnoses.csv</td><td>diagnoses.csv</td><td>5332265</td><td>1779297413000</td></tr><tr><td>abfss://landing@adlshospitaldwh.dfs.core.windows.net/encounters.csv</td><td>encounters.csv</td><td>7937550</td><td>1779297418000</td></tr><tr><td>abfss://landing@adlshospitaldwh.dfs.core.windows.net/lab_tests.csv</td><td>lab_tests.csv</td><td>5774431</td><td>1779297413000</td></tr><tr><td>abfss://landing@adlshospitaldwh.dfs.core.windows.net/medications.csv</td><td>medications.csv</td><td>8347116</td><td>1779297420000</td></tr><tr><td>abfss://landing@adlshospitaldwh.dfs.core.windows.net/patients.csv</td><td>patients.csv</td><td>9364006</td><td>1779297423000</td></tr><tr><td>abfss://landing@adlshospitaldwh.dfs.core.windows.net/procedures.csv</td><td>procedures.csv</td><td>11606351</td><td>1779297418000</td></tr><tr><td>abfss://landing@adlshospitaldwh.dfs.core.windows.net/providers.csv</td><td>providers.csv</td><td>168720</td><td>1779297416000</td></tr></tbody></table></div>
